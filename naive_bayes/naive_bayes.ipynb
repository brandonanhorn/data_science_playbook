# %% [markdown]
# # Naive Bayes

# %%
import pandas as pd

# %%
df = pd.read_csv('data/processed_tweets.csv')

# %%
df.dropna(inplace=True)

# %%
df.reset_index(drop=True, inplace=True)

# %%
df = df[[
    'audience_feature',
    'bias_feature',
    'message_feature',
    'label_feature',
    'source_feature',
    'text_feature'
]]

# %%
df['label_feature'].value_counts()
# Out:
# From: Ileana Ros-Lehtinen (Representative from Florida)         76
# From: Kevin Brady (Representative from Texas)                   69
# From: John Fleming (Representative from Louisiana)              48
# From: Cory Booker (Senator from New Jersey)                     47
# From: Bernard Sanders (Senator from Vermont)                    40
# From: Kyrsten Sinema (Representative from Arizona)              37
# From: Todd Rokita (Representative from Indiana)                 35
# From: Michael Crapo (Senator from Idaho)                        34
# From: John Cornyn (Senator from Texas)                          33
# From: Darrell Issa (Representative from California)             33
# From: Niki Tsongas (Representative from Massachusetts)          32
# From: Bill Flores (Representative from Texas)                   31
# From: Eric Swalwell (Representative from California)            29
# From: Michael Fitzpatrick (Representative from Pennsylvania)    28
# From: John Boehner (Representative from Ohio)                   28
# From: Steve Pearce (Representative from New Mexico)             28
# From: Debbie Wasserman Schultz (Representative from Florida)    28
# From: Steny Hoyer (Representative from Maryland)                27
# From: Lynn Jenkins (Representative from Kansas)                 26
# From: Heidi Heitkamp (Senator from North Dakota)                25
# From: Dana Rohrabacher (Representative from California)         25
# From: Robert Pittenger (Representative from North Carolina)     24
# From: Frank Pallone (Representative from New Jersey)            24
# From: John Carter (Representative from Texas)                   24
# From: Mike Quigley (Representative from Illinois)               24
# From: Mitch McConnell (Senator from Kentucky)                   24
# From: Tim Huelskamp (Representative from Kansas)                24
# From: Ted Cruz (Senator from Texas)                             23
# From: Marsha Blackburn (Representative from Tennessee)          23
# From: David Schweikert (Representative from Arizona)            22
#                                                                 ..
# From: Bill Keating (Representative from Massachusetts)           1
# From: Paul Ryan (Representative from Wisconsin)                  1
# From: Marcy Kaptur (Representative from Ohio)                    1
# From: Mike McIntyre (Representative from North Carolina)         1
# From: Mike Johanns (Senator from Nebraska)                       1
# From: Michael Michaud (Representative from Maine)                1
# From: John Tierney (Representative from Massachusetts)           1
# From: Henry Waxman (Representative from California)              1
# From: Adrian Smith (Representative from Nebraska)                1
# From: Dan Maffei (Representative from New York)                  1
# From: Ted Yoho (Representative from Florida)                     1
# From: Alan Nunnelee (Representative from Mississippi)            1
# From: Don Young (Representative from Alaska)                     1
# From: Trent Franks (Representative from Arizona)                 1
# From: William Cowan (Senator from Massachusetts)                 1
# From: Jim Matheson (Representative from Utah)                    1
# From: Rush Holt (Representative from New Jersey)                 1
# From: Mike Doyle (Representative from Pennsylvania)              1
# From: Brad Sherman (Representative from California)              1
# From: Jack Kingston (Representative from Georgia)                1
# From: Tom Coburn (Senator from Oklahoma)                         1
# From: Ralph Hall (Representative from Texas)                     1
# From: John Campbell (Representative from California)             1
# From: Duncan Hunter (Representative from California)             1
# From: Howard Coble (Representative from North Carolina)          1
# From: Jo Ann Emerson (Representative from Missouri)              1
# From: Colleen Hanabusa (Representative from Hawaii)              1
# From: Peter King (Representative from New York)                  1
# From: Mike Grimm (Representative from New York)                  1
# From: Alcee Hastings (Representative from Florida)               1
# Name: label_feature, Length: 501, dtype: int64

# %%
df
# Out:
#      audience_feature bias_feature message_feature  \
# 0            national     partisan          policy
# 1            national     partisan          attack
# 2            national      neutral         support
# 3            national      neutral          policy
# 4            national     partisan          policy
# 5            national      neutral    mobilization
# 6        constituency      neutral    mobilization
# 7            national      neutral        personal
# 8            national     partisan         support
# 9            national     partisan          policy
# 10           national     partisan          attack
# 11           national      neutral          policy
# 12           national      neutral     information
# 13       constituency      neutral        personal
# 14           national     partisan          policy
# 15           national      neutral        personal
# 16           national      neutral         support
# 17           national      neutral         support
# 18           national     partisan         support
# 19           national      neutral         support
# 20           national      neutral           other
# 21           national      neutral          policy
# 22           national      neutral          policy
# 23       constituency      neutral    constituency
# 24           national     partisan         support
# 25           national      neutral        personal
# 26           national     partisan          attack
# 27           national     partisan          policy
# 28           national      neutral     information
# 29           national     partisan          attack
# ...               ...          ...             ...
# 4746         national      neutral         support
# 4747         national      neutral     information
# 4748         national     partisan          attack
# 4749         national      neutral          policy
# 4750         national     partisan    mobilization
# 4751         national      neutral        personal
# 4752     constituency      neutral        personal
# 4753         national     partisan     information
# 4754     constituency      neutral    mobilization
# 4755         national      neutral          policy
# 4756     constituency      neutral    constituency
# 4757     constituency      neutral    constituency
# 4758     constituency      neutral        personal
# 4759         national      neutral        personal
# 4760         national      neutral         support
# 4761         national      neutral          policy
# 4762     constituency      neutral         support
# 4763         national      neutral          policy
# 4764         national      neutral         support
# 4765     constituency     partisan    mobilization
# 4766         national      neutral          policy
# 4767         national      neutral        personal
# 4768         national      neutral        personal
# 4769         national      neutral           media
# 4770         national      neutral          policy
# 4771         national      neutral          policy
# 4772         national      neutral     information
# 4773         national      neutral         support
# 4774         national      neutral        personal
# 4775         national      neutral        personal
#
#                                           label_feature source_feature  \
# 0        From: Trey Radel (Representative from Florida)        twitter
# 1         From: Mitch McConnell (Senator from Kentucky)        twitter
# 2      From: Kurt Schrader (Representative from Oregon)        twitter
# 3              From: Michael Crapo (Senator from Idaho)        twitter
# 4              From: Mark Udall (Senator from Colorado)        twitter
# 5     From: Frederica Wilson (Representative from Fl...        twitter
# 6        From: Ron Barber (Representative from Arizona)        twitter
# 7     From: Chuck Fleischmann (Representative from T...        twitter
# 8      From: Steny Hoyer (Representative from Maryland)        twitter
# 9     From: John Fleming (Representative from Louisi...        twitter
# 10    From: Adam Kinzinger (Representative from Illi...        twitter
# 11          From: Thomas Carper (Senator from Delaware)        twitter
# 12    From: Gregg Harper (Representative from Missis...        twitter
# 13    From: John Dingell (Representative from Michigan)        twitter
# 14     From: Kirsten Gillibrand (Senator from New York)        twitter
# 15          From: Cory Booker (Senator from New Jersey)        twitter
# 16    From: Elizabeth Esty (Representative from Conn...        twitter
# 17     From: Eric Cantor (Representative from Virginia)        twitter
# 18      From: Paul Tonko (Representative from New York)        twitter
# 19             From: Michael Crapo (Senator from Idaho)        twitter
# 20                From: Orrin Hatch (Senator from Utah)        twitter
# 21    From: Niki Tsongas (Representative from Massac...        twitter
# 22    From: Kerry Bentivolio (Representative from Mi...        twitter
# 23      From: Pete Sessions (Representative from Texas)        twitter
# 24    From: John Rockefeller IV (Senator from West V...        twitter
# 25    From: Steve Womack (Representative from Arkansas)        twitter
# 24    This wkÛªs 1 min video is on how expanding Me...
# 25    Thinking of all those affected by the severe w...
# 26    Remember Bill? He and his friends are stuck on...
# 27    Slashing AmtrakÛªs funding by 1/3 at a time o...
# 28    American #energy production is creating #jobs,...
# 29    #Obamacare spawning a new concept: "medical ho...
# ...                                                 ...
# 4746  Holding my fourth town hall this week in Fossi...
# 4747  It's that time of year again! I will be kickin...
# 4748  Even members of his own party are frustrated w...
# 4749  This morning, HHS Secretary Kathleen Sebelius ...
# 4750  Looking forward to talking with constituents l...
# 4751  Last week, while visiting with our troops over...
# 4752  Continuing to pray for all of those affected b...
# 4753  This morning, I took calls from constituents t...
# 4754  Where is your favorite place in the Third Dist...
# 4755  While we are a war-weary nation, we close rank...
# 4756  Florida State Parks are celebrating literacy t...
# 4757  Hosted a Senior Safety Fair today at Century V...
# 4758  It just got easier to return to the USA at For...
# 4759  Thank you to Girls Inc. for the Power of the P...
# 4760  IÛªll be talking with Michael Putney at 11:30...
# 4761  Contrary to its name, the Working Families Fle...
# 4762  Visited with Mrs. PerezÛªs 3rd grade class at...
# 4763  Troop Capitol Hill is proud of our @girlscouts...
# 4764  Tune in to News Radio 610 this morning - I'll ...
# 4765  What should be the top priorities for Congress...
# 4766  Tomorrow the House will consider a package of ...
# 4767  The Goetz Family from Dexter squeezed onto my ...
# 4768  I had the great opportunity to speak with 8th ...
# 4769  Please read, share and like my latest column i...
# 4770  Our children are being held back by an outdate...
# 4771  I introduced legislation with Rep Kildee to he...
# 4772  July 1 ÛÒ Peter participated with Chairman Pa...
# 4773  TUNE IN: PeterÛªs interview on Channel 3Ûªs ...
# 4774  Peter strongly supports the efforts of Senator...
# 4775  LIKE AND SHARE TO HIGH FIVE RUTLAND\n \n In th...
#
# [4776 rows x 6 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
y = df['bias_feature']
X = df[['text_feature']]
y = y.replace({'partisan': 1, 'neutral': 0})

# %%
1 - y.mean()
# Out:
# 0.7395309882747069

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
from sklearn_pandas import DataFrameMapper
from sklearn.feature_extraction.text import CountVectorizer

# %%
mapper = DataFrameMapper([
    ['text_feature', CountVectorizer()]
], df_out=True)

# %%
Z_train = mapper.fit_transform(X_train)
Z_test = mapper.transform(X_test)

# %% [markdown]
# #### 4. Fit a Naive Bayes model!
#
# <details><summary> Which Naive Bayes model should we pick, and why? </summary>
# ```
# - The columns of X are all integer counts, so MultinomialNB is the best choice here.
# - BernoulliNB is best when we have 0/1 counts in all columns of X. (a.k.a. dummy variables)
# - GaussianNB is best when the columns of X are Normally distributed. (Practically, though, it gets used whenever BernoulliNB and MultinomialNB are inappropriate.)
# ```
# </details>

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
model = MultinomialNB()

# %% [markdown]
# Remember earlier that I said we had the opportunity to set priors. We could do so here if we wanted, but we'll stick with the default and allow `sklearn` to estimate priors from the training data directly.

# %%
model.fit(Z_train, y_train)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
predictions = model.predict(Z_test)

# %%
model.score(Z_train, y_train)
# Out:
# 0.9154103852596315

# %%
model.score(Z_test, y_test)
# Out:
# 0.7705192629815746

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_test, predictions)
# Out:
# array([[776,  86],
#        [188, 144]])

# %%
tn, fp, fn, tp = confusion_matrix(y_test, predictions).ravel()

# %%
print("True Negatives: %s" % tn)
print("False Positives: %s" % fp)
print("False Negatives: %s" % fn)
print("True Positives: %s" % tp)
# Out:
# True Negatives: 776
# False Positives: 86
# False Negatives: 188
# True Positives: 144
